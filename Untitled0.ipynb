# %% [markdown]
# <a href="https://colab.research.google.com/github/cristianjuniorcaceresrocha-stack/matrices-inteligencia-artificial/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World Cristian Caceres")
# Out:
# Hello World Cristian Caceres
